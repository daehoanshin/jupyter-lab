# %%
print("Hello World")
# Out:
# Hello World

# %%
print("환영합니다.")
# Out:
# 환영합니다.

# %%
name = "연탄이"
print(name)
# Out:
# 연탄이

# %%
print("Ctrl + Enter : 현재 Cell 실행")
# Out:
# Ctrl + Enter : 현재 Cell 실행

# %%
print("Shift + Enter : 현재 Cell 실행 후 다음 위치에 Cell 삽입")
# Out:
# Shift + Enter : 현재 Cell 실행 후 다음 위치에 Cell 삽입

# %%
print(1)
print(2
print(3)
# Out:
#   File "<ipython-input-12-e17995684497>", line 3
#     print(3)
#     ^
# SyntaxError: invalid syntax
